# %%
#Exercício 3
dolar = float(input("Digite o valor em dolar "))
cotacao = float(input("Digite a cotacao do dolar "))
conversao = dolar * cotacao
print('%.2f dólares são %.2f reais' % (dolar, conversao))
# Out:
# 100.00 dólares são 327.00 reais

# %%
#Exercício 8
numero = int(input("Digite seu valor "))
if (numero % 3 == 0 and numero % 5 == 0):
    print("False")
else:
    if (numero % 3 == 0 or numero % 5 == 0):
        print("True")
    else:
        print("False")
# Out:
# Digite seu valor 56
# False

# %%
#Exercício 13
n = int(input("Digite o primeiro valor "))
m = int(input("Digite o segundo valor "))
for i in range(n,m,1):
    if (i%2 != 0):
        print(i)
# Out:
# Digite o primeiro valor 1
# Digite o segundo valor 10
# 2
# 4
# 6
# 8

# %%
#Exercício 18.e
def hora(h, m, s):
    s+=1
    if s==60:
        s = 0
        m += 1
    if m == 60:
        m = 0
        h += 1
    if h == 24:
        h = m = s = 0
    print("%d:%d:%d"% (h,m,s))


hora(23,59,59)
# Out:
# 0:0:0
